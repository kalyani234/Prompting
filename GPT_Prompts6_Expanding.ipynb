# %% [markdown]
# <a href="https://colab.research.google.com/github/kalyani234/Prompting/blob/main/GPT_Prompts6_Expanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Expanding - Temperature

# %%
from google.colab import userdata
from openai import OpenAI

client = OpenAI(api_key=userdata.get("open_api"))

def get_completion(prompt, model="gpt-4o-mini", temperature=0):
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=temperature, # this is the degree of randomness of the model's output

    )
    return response.choices[0].message.content

# %% [markdown]
# Customize the automated reply to a customer email

# %%
# given the sentiment from the lesson on "inferring",
# and the original customer message, customize the email
sentiment = "negative"

# review for a blender
review = f"""
So, they still had the 17 piece system on seasonal
sale for around $49 in the month of November, about
half off, but for some reason (call it price gouging)
around the second week of December the prices all went
up to about anywhere from between $70-$89 for the same
system. And the 11 piece system went up around $10 or
so in price also from the earlier sale price of $29.
So it looks okay, but if you look at the base, the part
where the blade locks into place doesn’t look as good
as in previous editions from a few years ago, but I
plan to be very gentle with it (example, I crush
very hard items like beans, ice, rice, etc. in the
blender first then pulverize them in the serving size
I want in the blender then switch to the whipping
blade for a finer flour, and use the cross cutting blade
first when making smoothies, then use the flat blade
if I need them finer/less pulpy). Special tip when making
smoothies, finely cut and freeze the fruits and
vegetables (if using spinach-lightly stew soften the
spinach then freeze until ready for use-and if making
sorbet, use a small to medium sized food processor)
that you plan to use that way you can avoid adding so
much ice if at all-when making your smoothie.
After about a year, the motor was making a funny noise.
I called customer service but the warranty expired
already, so I had to buy another one. FYI: The overall
quality has gone done in these types of products, so
they are kind of counting on brand recognition and
consumer loyalty to maintain sales. Got it in about
two days.
"""

# %% [markdown]
# Remind the model to use details from the customer's email

# %%
prompt = f"""
You are a customer service AI assistant.
Your task is to send an email reply to a valued customer.
Given the customer email delimited by ```, \
Generate a reply to thank the customer for their review.
If the sentiment is positive or neutral, thank them for \
their review.
If the sentiment is negative, apologize and suggest that \
they can reach out to customer service.
Make sure to use specific details from the review.
Write in a concise and professional tone.
Sign the email as `AI customer agent`.
Customer review: ```{review}```
Review sentiment: {sentiment}
"""
response = get_completion(prompt, temperature=0.7)
print(response)
# Out:
# Subject: Thank You for Your Feedback
#
# Dear Valued Customer,
#
# Thank you for taking the time to share your insights regarding your recent experience with our product. We sincerely apologize for the issues you've encountered, particularly with the price fluctuations and the decline in quality you observed. Your feedback is invaluable, and we take such concerns seriously as we strive to improve our offerings.
#
# If you would like further assistance or have any unresolved issues, please do not hesitate to reach out to our customer service team. We are here to help and would appreciate the opportunity to address your concerns.
#
# Thank you once again for your review.
#
# Best regards,
# AI customer agent

# %%
prompt = f"""
You are a customer service AI assistant.
Your task is to send an email reply to a valued customer.
Given the customer email delimited by ```, \
Generate a reply to thank the customer for their review.
If the sentiment is positive or neutral, thank them for \
their review.
If the sentiment is negative, apologize and suggest that \
they can reach out to customer service.
Make sure to use specific details from the review.
Write in a concise and professional tone.
Sign the email as `AI customer agent`.
Customer review: ```{review}```
Review sentiment: {sentiment}
"""
response = get_completion(prompt, temperature=0.3)
print(response)
# Out:
# Subject: Thank You for Your Feedback
#
# Dear Valued Customer,
#
# Thank you for taking the time to share your thoughts regarding your recent experience with our products. We sincerely apologize for the issues you've encountered, particularly with the price changes and the quality of the system you received. Your feedback is invaluable to us, and we take your concerns seriously.
#
# If you would like to discuss this further or need assistance, please do not hesitate to reach out to our customer service team. We are here to help and ensure that you have a satisfactory experience with our products.
#
# Thank you once again for your feedback.
#
# Best regards,
#
# AI Customer Agent

# %%
sentiment = "negative"
review2 = """
I like this air fryer, even with this issue. However after a discussion with amazon they are unable to supply a replacement or equal quality part so Ive been recommended to send this back.

The instruction booklet isn't great, I would underestimate your cooks at first rather than using the same as in a normal oven. What would take 25 minutes at 200 in my old oven, takes 15 at 200 here. It's great, much cheaper than the large oven according to my smart meter so was very happy. Ive used it a handful of times, and the basket (the larger metal tray) 3 times.

Unfortunately the underside of the lip and the holes of the rivets don't seem to have been finished and sealed properly, I imagine it's a rough edge that hasn't been painted and it's rusting. I don't leave the basket in water, I wash and dry it fine, but unfortunately after only 3 washes this issue has developed. I imagine it's because water seeps where I can't properly get to and it's causing issues due to the lack of proper finishing.
"""

# %%
prompt = f"""
You are a customer service AI assistant.
Your task is to send an email reply to a valued customer.
Given the customer email delimited by ```, \
Generate a reply to thank the customer for their review.
If the sentiment is positive or neutral, thank them for \
their review.
If the sentiment is negative, apologize and suggest that \
they can reach out to customer service.
Make sure to use specific details from the review.
Write in a concise and professional tone.
Sign the email as `AI customer agent`.
Customer review: ```{review2}```
Review sentiment: {sentiment}
"""
response = get_completion(prompt, temperature=0.2)
print(response)
# Out:
# Subject: Thank You for Your Feedback
#
# Dear Valued Customer,
#
# Thank you for taking the time to share your experience with our air fryer. We appreciate your feedback, and I’m sorry to hear about the issues you’ve encountered, particularly with the rusting and the instruction booklet.
#
# We strive to provide high-quality products, and it’s disappointing to learn that we fell short in this instance. I recommend reaching out to our customer service team for assistance with your concerns regarding the product. They will be happy to help you find a suitable solution.
#
# Thank you once again for your valuable feedback. We hope to resolve this matter to your satisfaction.
#
# Best regards,
#
# AI customer agent

# %%
text = """
Generate a dummy JSON request for a medical application that analyzes patient 2 3 symptoms and returns a diagnostic summary.

The JSON structure should contain:
- "patient_id"
- "symptoms"
- "requested_analysis"
- "meta" section with fields: "timestamp", "source"

Use realistic medical-style placeholder values.

"""

# %%
prompt = f"""
You are a backend API service AI assistant.
Your task is to create an JSON to a developer.
Given the developer email delimited by ```,
Write in a concise and professional tone.
Sign the email as `AI customer agent`.
Customer Request: ```{text}```
"""
response = get_completion(prompt, temperature=0.2)
print(response)
# Out:
# Subject: Dummy JSON Request for Medical Application
#
# Dear Developer,
#
# Please find below a dummy JSON request for a medical application that analyzes patient symptoms and returns a diagnostic summary.
#
# ```json
# {
#   "patient_id": "P123456",
#   "symptoms": [
#     "fever",
#     "cough",
#     "fatigue"
#   ],
#   "requested_analysis": "diagnostic_summary",
#   "meta": {
#     "timestamp": "2023-10-05T14:30:00Z",
#     "source": "mobile_app"
#   }
# }
# ```
#
# If you need any further assistance, feel free to reach out.
#
# Best regards,
#
# AI customer agent

# %% [markdown]
# # Temperature = 0.7 Halluctination

# %%
prompt = f"""
You are a backend API service AI assistant.
Your task is to create an JSON to a developer.
Given the developer email delimited by ```,
Write in a concise and professional tone.
Sign the email as `AI customer agent`.
Customer Request: ```{text}```
"""
response = get_completion(prompt, temperature=0.7)
print(response)
# Out:
# Subject: Dummy JSON Request for Medical Application
#
# Dear Developer,
#
# Please find below a dummy JSON request structure for your medical application that analyzes patient symptoms and returns a diagnostic summary.
#
# ```json
# {
#   "patient_id": "PATIENT-12345",
#   "symptoms": [
#     {
#       "name": "Fever",
#       "duration": "2 days",
#       "severity": "moderate"
#     },
#     {
#       "name": "Cough",
#       "duration": "3 days",
#       "severity": "mild"
#     }
#   ],
#   "requested_analysis": "Diagnostic summary based on provided symptoms",
#   "meta": {
#     "timestamp": "2023-10-01T14:30:00Z",
#     "source": "mobile_app"
#   }
# }
# ```
#
# Let me know if you need any further assistance.
#
# Best regards,
#
# AI Customer Agent
